# %% [markdown]
# <a href="https://colab.research.google.com/github/jhavishakha-tech/IDS_LAB/blob/main/Vishakha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load data
data = pd.read_csv("https://raw.githubusercontent.com/defcom17/NSL_KDD/master/KDDTrain+.txt", header=None)

# Encode text to numbers
le = LabelEncoder()
for i in [1, 2, 3, 41]:
    data[i] = le.fit_transform(data[i])

# Split data
X = data.drop(41, axis=1)
y = data[41]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Train model
model = DecisionTreeClassifier(max_depth=2)
model.fit(X_train, y_train)

# Predict & accuracy
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.871718882303133
